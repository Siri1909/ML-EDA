# %%
#1.create dataframe
import pandas as pd
df = pd.read_csv('/content/student-mat.csv')
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
df.shape#395 rows and 33 columns
# Out:
# (395, 33)

# %%
df.size#total number of elements
# Out:
# 13035

# %%
#to check null values
df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
df.nunique()
# Out:
# school         2
# sex            2
# age            8
# address        2
# famsize        2
# Pstatus        2
# Medu           5
# Fedu           5
# Mjob           5
# Fjob           5
# reason         4
# guardian       3
# traveltime     4
# studytime      4
# failures       4
# schoolsup      2
# famsup         2
# paid           2
# activities     2
# nursery        2
# higher         2
# internet       2
# romantic       2
# famrel         5
# freetime       5
# goout          5
# Dalc           5
# Walc           5
# health         5
# absences      34
# G1            17
# G2            17
# G3            18
# dtype: int64

# %%
#3.VISULISATION - seabron - for age
import seaborn as sns
sns.distplot(df['age'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#This count plot will tell us number of ages
import matplotlib.pyplot as plt
f=plt.figure()
f.set_figwidth(12)
f.set_figheight(5)
plt.plot()
sns.countplot(x = 'age',data = df)
plt.xticks(rotation = 'vertical')
plt.show()

# %%
df.groupby('age').size()
# Out:
# age
# 15     82
# 16    104
# 17     98
# 18     82
# 19     24
# 20      3
# 21      1
# 22      1
# dtype: int64

# %%
df['age'].value_counts()
# Out:
# 16    104
# 17     98
# 18     82
# 15     82
# 19     24
# 20      3
# 22      1
# 21      1
# Name: age, dtype: int64

# %%
import matplotlib.pyplot as plt
f=plt.figure()
f.set_figwidth(15)
f.set_figheight(5)
plt.plot()
df['age'].value_counts().plot(kind = 'bar')
plt.xticks(rotation = 'vertical')
plt.show()

# %%
import matplotlib.pyplot as plt
f=plt.figure()
f.set_figwidth(12)
f.set_figheight(5)
plt.plot()
sns.barplot(x = df['sex'],y = df['age'])
plt.xticks(rotation = 'horizontal')
plt.show()

# %%
import numpy as np
np.min(df['age'])
# Out:
# 15

# %%
np.max(df['age'])
# Out:
# 22

# %%
#3.VISULISATION - seabron - for Medu (mother education)
import seaborn as sns
sns.distplot(df['Medu'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import matplotlib.pyplot as plt
f=plt.figure()
f.set_figwidth(12)
f.set_figheight(5)
plt.plot()
sns.countplot(x = 'Medu',data = df)
plt.xticks(rotation = 'horizontal')
plt.show()

# %%
df.groupby('Medu').size()
# Out:
# Medu
# 0      3
# 1     59
# 2    103
# 3     99
# 4    131
# dtype: int64

# %%
df['Medu'].value_counts()
# Out:
# 4    131
# 2    103
# 3     99
# 1     59
# 0      3
# Name: Medu, dtype: int64

# %%
import matplotlib.pyplot as plt
f=plt.figure()
f.set_figwidth(15)
f.set_figheight(5)
plt.plot()
df['Medu'].value_counts().plot(kind = 'bar')
plt.xticks(rotation = 'vertical')
plt.show()

# %%
import matplotlib.pyplot as plt
f=plt.figure()
f.set_figwidth(12)
f.set_figheight(5)
plt.plot()
sns.barplot(x = df['Mjob'],y = df['Medu'])
plt.xticks(rotation = 'horizontal')
plt.show()

# %%
import numpy as np
np.min(df['Medu'])
# Out:
# 0

# %%
np.max(df['Medu'])
# Out:
# 4

# %%
#3.VISULISATION - seabron - for Fedu (father education)
import seaborn as sns
sns.distplot(df['Fedu'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import matplotlib.pyplot as plt
f=plt.figure()
f.set_figwidth(12)
f.set_figheight(5)
plt.plot()
sns.countplot(x = 'Fedu',data = df)
plt.xticks(rotation = 'horizontal')
plt.show()

# %%
df.groupby('Fedu').size()
# Out:
# Fedu
# 0      2
# 1     82
# 2    115
# 3    100
# 4     96
# dtype: int64

# %%
df['Fedu'].value_counts()
# Out:
# 2    115
# 3    100
# 4     96
# 1     82
# 0      2
# Name: Fedu, dtype: int64

# %%
import matplotlib.pyplot as plt
f=plt.figure()
f.set_figwidth(15)
f.set_figheight(5)
plt.plot()
df['Fedu'].value_counts().plot(kind = 'bar')
plt.xticks(rotation = 'vertical')
plt.show()

# %%
import matplotlib.pyplot as plt
f=plt.figure()
f.set_figwidth(12)
f.set_figheight(5)
plt.plot()
sns.barplot(x = df['Fjob'],y = df['Fedu'])
plt.xticks(rotation = 'horizontal')
plt.show()

# %%
import numpy as np
np.min(df['Fedu'])
# Out:
# 0

# %%
np.max(df['Fedu'])
# Out:
# 4

# %%
#3.VISULISATION - seabron - for traveltime
import seaborn as sns
sns.distplot(df['traveltime'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import matplotlib.pyplot as plt
f=plt.figure()
f.set_figwidth(12)
f.set_figheight(5)
plt.plot()
sns.countplot(x = 'traveltime',data = df)
plt.xticks(rotation = 'horizontal')
plt.show()

# %%
df.groupby('traveltime').size()
# Out:
# traveltime
# 1    257
# 2    107
# 3     23
# 4      8
# dtype: int64

# %%
df['traveltime'].value_counts()
# Out:
# 1    257
# 2    107
# 3     23
# 4      8
# Name: traveltime, dtype: int64

# %%
import matplotlib.pyplot as plt
f=plt.figure()
f.set_figwidth(15)
f.set_figheight(5)
plt.plot()
df['traveltime'].value_counts().plot(kind = 'bar')
plt.xticks(rotation = 'vertical')
plt.show()

# %%
import matplotlib.pyplot as plt
f=plt.figure()
f.set_figwidth(12)
f.set_figheight(5)
plt.plot()
sns.barplot(x = df['school'],y = df['traveltime'])
plt.xticks(rotation = 'horizontal')
plt.show()

# %%
import numpy as np
np.min(df['traveltime'])
# Out:
# 1

# %%
np.max(df['traveltime'])
# Out:
# 4

# %%
#3.VISULISATION - seabron - for studytime
import seaborn as sns
sns.distplot(df['studytime'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import matplotlib.pyplot as plt
f=plt.figure()
f.set_figwidth(12)
f.set_figheight(5)
plt.plot()
sns.countplot(x = 'studytime',data = df)
plt.xticks(rotation = 'horizontal')
plt.show()

# %%
df.groupby('studytime').size()
# Out:
# studytime
# 1    105
# 2    198
# 3     65
# 4     27
# dtype: int64

# %%
df['studytime'].value_counts()
# Out:
# 2    198
# 1    105
# 3     65
# 4     27
# Name: studytime, dtype: int64

# %%
import matplotlib.pyplot as plt
f=plt.figure()
f.set_figwidth(5)
f.set_figheight(5)
plt.plot()
df['studytime'].value_counts().plot(kind = 'bar')
plt.xticks(rotation = 'vertical')
plt.show()

# %%
import matplotlib.pyplot as plt
f=plt.figure()
f.set_figwidth(5)
f.set_figheight(5)
plt.plot()
sns.barplot(x = df['school'],y = df['studytime'])
plt.xticks(rotation = 'horizontal')
plt.show()

# %%
import numpy as np
np.min(df['studytime'])
# Out:
# 1

# %%
np.max(df['studytime'])
# Out:
# 4

# %%
#3.VISULISATION - seabron - for failures
import seaborn as sns
sns.distplot(df['failures'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import matplotlib.pyplot as plt
f=plt.figure()
f.set_figwidth(5)
f.set_figheight(5)
plt.plot()
sns.countplot(x = 'failures',data = df)
plt.xticks(rotation = 'horizontal')
plt.show()

# %%
df.groupby('failures').size()
# Out:
# failures
# 0    312
# 1     50
# 2     17
# 3     16
# dtype: int64

# %%
df['failures'].value_counts()
# Out:
# 0    312
# 1     50
# 2     17
# 3     16
# Name: failures, dtype: int64

# %%
import matplotlib.pyplot as plt
f=plt.figure()
f.set_figwidth(5)
f.set_figheight(5)
plt.plot()
df['failures'].value_counts().plot(kind = 'bar')
plt.xticks(rotation = 'horizontal')
plt.show()

# %%
import matplotlib.pyplot as plt
f=plt.figure()
f.set_figwidth(5)
f.set_figheight(5)
plt.plot()
sns.barplot(x = df['sex'],y = df['failures'])
plt.xticks(rotation = 'horizontal')
plt.show()

# %%
import numpy as np
np.min(df['failures'])
# Out:
# 0

# %%
np.max(df['failures'])
# Out:
# 3

# %%
#VISULISATION - seabron - for schoolsup
import matplotlib.pyplot as plt
f=plt.figure()
f.set_figwidth(5)
f.set_figheight(5)
plt.plot()
sns.countplot(x = 'schoolsup',data = df)
plt.xticks(rotation = 'horizontal')
plt.show()

# %%
df.groupby('schoolsup').size()
# Out:
# schoolsup
# no     344
# yes     51
# dtype: int64

# %%
df['schoolsup'].value_counts()
# Out:
# no     344
# yes     51
# Name: schoolsup, dtype: int64

# %%
import matplotlib.pyplot as plt
f=plt.figure()
f.set_figwidth(5)
f.set_figheight(5)
plt.plot()
df['schoolsup'].value_counts().plot(kind = 'bar')
plt.xticks(rotation = 'horizontal')
plt.show()

# %%
import matplotlib.pyplot as plt
f=plt.figure()
f.set_figwidth(5)
f.set_figheight(5)
plt.plot()
sns.barplot(x = df['schoolsup'],y = df['failures'])
plt.xticks(rotation = 'horizontal')
plt.show()

# %%
import numpy as np
np.min(df['schoolsup'])
# Out:
# 'no'

# %%
np.max(df['schoolsup'])
# Out:
# 'yes'

# %%
#VISULISATION - for famsup (familysup)
import matplotlib.pyplot as plt
f=plt.figure()
f.set_figwidth(5)
f.set_figheight(5)
plt.plot()
sns.countplot(x = 'famsup',data = df)
plt.xticks(rotation = 'horizontal')
plt.show()

# %%
df.groupby('famsup').size()
# Out:
# famsup
# no     153
# yes    242
# dtype: int64

# %%
df['famsup'].value_counts()
# Out:
# yes    242
# no     153
# Name: famsup, dtype: int64

# %%
import matplotlib.pyplot as plt
f=plt.figure()
f.set_figwidth(5)
f.set_figheight(5)
plt.plot()
df['famsup'].value_counts().plot(kind = 'bar')
plt.xticks(rotation = 'horizontal')
plt.show()

# %%
import matplotlib.pyplot as plt
f=plt.figure()
f.set_figwidth(5)
f.set_figheight(5)
plt.plot()
sns.barplot(x = df['famsup'],y = df['studytime'])
plt.xticks(rotation = 'horizontal')
plt.show()

# %%
import numpy as np
np.min(df['famsup'])
# Out:
# 'no'

# %%
np.max(df['famsup'])
# Out:
# 'yes'

# %%
#VISULISATION - for paid (paid)
import matplotlib.pyplot as plt
f=plt.figure()
f.set_figwidth(5)
f.set_figheight(5)
plt.plot()
sns.countplot(x = 'paid',data = df)
plt.xticks(rotation = 'horizontal')
plt.show()

# %%
df.groupby('paid').size()
# Out:
# paid
# no     214
# yes    181
# dtype: int64

# %%
df['paid'].value_counts()
# Out:
# no     214
# yes    181
# Name: paid, dtype: int64

# %%
import matplotlib.pyplot as plt
f=plt.figure()
f.set_figwidth(5)
f.set_figheight(5)
plt.plot()
df['paid'].value_counts().plot(kind = 'bar')
plt.xticks(rotation = 'horizontal')
plt.show()

# %%
import matplotlib.pyplot as plt
f=plt.figure()
f.set_figwidth(5)
f.set_figheight(5)
plt.plot()
sns.barplot(x = df['paid'],y = df['age'])
plt.xticks(rotation = 'horizontal')
plt.show()

# %%
import numpy as np
np.min(df['paid'])
# Out:
# 'no'

# %%
np.max(df['paid'])
# Out:
# 'yes'

# %%
#3.VISULISATION - seabron - for famrel
import seaborn as sns
sns.distplot(df['famrel'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import matplotlib.pyplot as plt
f=plt.figure()
f.set_figwidth(5)
f.set_figheight(5)
plt.plot()
sns.countplot(x = 'famrel',data = df)
plt.xticks(rotation = 'horizontal')
plt.show()

# %%
df.groupby('famrel').size()
# Out:
# famrel
# 1      8
# 2     18
# 3     68
# 4    195
# 5    106
# dtype: int64

# %%
df['famrel'].value_counts()
# Out:
# 4    195
# 5    106
# 3     68
# 2     18
# 1      8
# Name: famrel, dtype: int64

# %%
import matplotlib.pyplot as plt
f=plt.figure()
f.set_figwidth(5)
f.set_figheight(5)
plt.plot()
df['famrel'].value_counts().plot(kind = 'bar')
plt.xticks(rotation = 'horizontal')
plt.show()

# %%
import matplotlib.pyplot as plt
f=plt.figure()
f.set_figwidth(5)
f.set_figheight(5)
plt.plot()
sns.barplot(x = df['famsup'],y = df['famrel'])
plt.xticks(rotation = 'horizontal')
plt.show()

# %%
import numpy as np
np.min(df['famrel'])
# Out:
# 1

# %%
np.max(df['famrel'])
# Out:
# 5

# %%
#3.VISULISATION - seabron - for famrel
import seaborn as sns
sns.distplot(df['freetime'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import matplotlib.pyplot as plt
f=plt.figure()
f.set_figwidth(5)
f.set_figheight(5)
plt.plot()
sns.countplot(x = 'freetime',data = df)
plt.xticks(rotation = 'horizontal')
plt.show()

# %%
df.groupby('freetime').size()
# Out:
# freetime
# 1     19
# 2     64
# 3    157
# 4    115
# 5     40
# dtype: int64

# %%
df['freetime'].value_counts()
# Out:
# 3    157
# 4    115
# 2     64
# 5     40
# 1     19
# Name: freetime, dtype: int64

# %%
import matplotlib.pyplot as plt
f=plt.figure()
f.set_figwidth(5)
f.set_figheight(5)
plt.plot()
df['freetime'].value_counts().plot(kind = 'bar')
plt.xticks(rotation = 'horizontal')
plt.show()

# %%
import matplotlib.pyplot as plt
f=plt.figure()
f.set_figwidth(5)
f.set_figheight(5)
plt.plot()
sns.barplot(x = df['famsup'],y = df['freetime'])
plt.xticks(rotation = 'horizontal')
plt.show()

# %%
import numpy as np
np.min(df['freetime'])
# Out:
# 1

# %%
np.max(df['freetime'])
# Out:
# 5
